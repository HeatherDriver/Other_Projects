# %%
! pip install llama-index-graph-stores-neo4j # Install Neo4j with LlamaIndex.
! pip install llama-index-embeddings-openai
! pip install llama-index-llms-openai
! pip install llama-index-readers-file
! pip install --upgrade llama-index
# Out:
# Requirement already satisfied: llama-index-graph-stores-neo4j in /usr/local/lib/python3.11/dist-packages (0.4.6)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-graph-stores-neo4j) (0.12.23.post2)
# Requirement already satisfied: neo4j<6.0.0,>=5.16.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-graph-stores-neo4j) (5.28.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.11.13)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.17.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j<6.0.0,>=5.16.0->llama-index-graph-stores-neo4j) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.18.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.26.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.3.1)
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.11/dist-packages (0.3.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-openai) (0.12.23.post2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-openai) (1.61.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.11.13)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.2)
# Requirement already satisfied: llama-index-llms-openai in /usr/local/lib/python3.11/dist-packages (0.3.25)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.17 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai) (0.12.23.post2)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai) (1.61.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.11.13)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (24.2)
# Requirement already satisfied: llama-index-readers-file in /usr/local/lib/python3.11/dist-packages (0.4.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file) (4.13.3)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file) (0.12.23.post2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file) (2.2.2)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file) (5.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (4.12.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.11.13)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.18.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.26.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.1)
# Collecting llama-index
#   Downloading llama_index-0.12.23-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-agent-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.6-py3-none-any.whl.metadata (727 bytes)
# Collecting llama-index-cli<0.5.0,>=0.4.1 (from llama-index)
#   Downloading llama_index_cli-0.4.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.23 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.12.23.post2)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.1)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.8-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.25)
# Collecting llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.6)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.61.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.23->llama-index) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (3.11.13)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (2024.10.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13.0,>=0.12.23->llama-index) (1.17.2)
# Collecting llama-cloud<0.2.0,>=0.1.13 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.14-py3-none-any.whl.metadata (902 bytes)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.13.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.6.4.post1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.23->llama-index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from llama-cloud<0.2.0,>=0.1.13->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.1.31)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.23->llama-index) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.23->llama-index) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.23->llama-index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.23->llama-index) (0.14.0)
# Collecting llama-cloud-services>=0.6.4 (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_cloud_services-0.6.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.23->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.23->llama-index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.23->llama-index) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.23->llama-index) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.23->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.23->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.23->llama-index) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2025.1)
# Collecting python-dotenv<2.0.0,>=1.0.1 (from llama-cloud-services>=0.6.4->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.23->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.17.0)
# Downloading llama_index-0.12.23-py3-none-any.whl (7.0 kB)
# Downloading llama_index_agent_openai-0.4.6-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.4.1-py3-none-any.whl (28 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.8-py3-none-any.whl (13 kB)
# Downloading llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading llama_cloud-0.1.14-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 11.5 MB/s eta 0:00:00
# Downloading llama_parse-0.6.4.post1-py3-none-any.whl (4.9 kB)
# Downloading llama_cloud_services-0.6.5-py3-none-any.whl (28 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, llama-cloud, llama-index-indices-managed-llama-cloud, llama-cloud-services, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed llama-cloud-0.1.14 llama-cloud-services-0.6.5 llama-index-0.12.23 llama-index-agent-openai-0.4.6 llama-index-cli-0.4.1 llama-index-indices-managed-llama-cloud-0.6.8 llama-index-multi-modal-llms-openai-0.4.3 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-llama-parse-0.4.0 llama-parse-0.6.4.post1 python-dotenv-1.0.1

# %%
from google.colab import drive, userdata
from llama_index.core import SimpleDirectoryReader
from llama_index.core import PropertyGraphIndex
from llama_index.embeddings.openai import OpenAIEmbedding
import os
import openai
from llama_index.core.indices.property_graph import SchemaLLMPathExtractor
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore
import nest_asyncio
import asyncio
from transformers import AutoTokenizer, DistilBertModel
import torch
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
from llama_index.core import StorageContext, load_index_from_storage

# %%
drive.mount("/content/drive")
# %cd '/content/drive/MyDrive/Colab Notebooks/Other/RAG'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Other/RAG

# %%
# Apply nest_asyncio for colab/jupyter notebook, not asyncio. This helps with running tasks concurrently to stop long execution times
nest_asyncio.apply()

# %% [markdown]
# # Defining Functions to perform Automated Search

# %% [markdown]
# ## Search Functions

# %%
def search_with_google_api(topic):
  """
  Performs a Google search programmatically using the Google Custom Search API.
  Returns a list of search results.
  """
  google_api = userdata.get('Google_API')
  search_engine_id = userdata.get('search_engine_id')
  url = f"https://www.googleapis.com/customsearch/v1?q={topic}&key={google_api}&cx={search_engine_id}"

  response = requests.get(url)
  if response.status_code == 200:
    return response.json().get("items", [])
  else:
    print(f"Error: {response.status_code}, {response.text}")
    return []

# %% [markdown]
# ## Using OpenAI to generate the search query

# %%
def gpt_answers(topic):
    """
    Generates a list of 5-7 detailed and relevant search queries for financial sentiment analysis
    based on the user's input, such as a target sector, field, or region.
    """
    API_key = userdata.get('ChatGPT')
    prompt = f"""
                You are a research analyst and search query expert. Based on the following topic, generate a list of 5-7 search queries
                for identifying approachable but relevant scientific research trends.
                Ensure the queries cover recent publications, breakthroughs, applications, and reviews, and are only relevant to recent findings.
                Do not mention the year in your queries.
                The queries should focus on extracting data relevant to academic and industry advancements.
                Output the queries as a plain Python list of strings without any Markdown formatting or code block markers.
                Example:

                Topic:
                AI-driven drug discovery in antibiotic resistance

                ['AI applications in recent antibiotic resistance research breakthroughs', 'AI drug discovery in antibiotic resistance recent publications', 'machine learning applications antibiotic resistance drug development',
                 'recent synthetic biology antibiotic resistance AI-driven approaches', 'new novel algorithms for drug discovery in antibiotic resistance']

                End of example.
                Topic: {topic} """

    client = OpenAI(api_key = API_key)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system",
             "content": "You are an expert in generating search queries for scientific research trends."},
            {"role": "user",
             "content": prompt}
        ],
        max_tokens=400
    )

    # Extract and clean up the list of queries
    queries =  response.choices[0].message.content.strip()

    # Remove Markdown code block markers if present
    if queries.startswith("```"):
      # Remove the first code fence and the language hint, then the closing code fence
      queries = queries.split("```")[1].strip()
    return eval(queries)

# %% [markdown]
# ## Parsing page results to paragraph components

# %%
def fetch_full_content(url):
  """
  Fetches the full content of a webpage given its URL.
  """
  headers = {
      "User-Agent": (
      "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
      "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
      )
  }
  try:
    response = requests.get(url, headers=headers, timeout=10)
    if response.status_code == 200:
      soup = BeautifulSoup(response.text, "html.parser")
      paragraphs = soup.find_all("p")
      full_text = "\n".join([p.get_text() for p in paragraphs])
      return full_text.strip() if full_text else None
    else:
      print(f"Error: Unable to fetch content from {url} (Status Code: {response.status_code})")
      return None
  except Exception as e:
    print(f"Error fetching content from {url}: {e}")
    return None

# %% [markdown]
# ## Creating documents for loading to database

# %%
def create_dataset_from_queries(queries, directory):
  """
  Processes search queries and save results as text files in the same directory.
  """
  if not os.path.exists(directory):
      os.makedirs(directory)

  file_count = 1  # To ensure unique filenames across all queries

  for query in queries:
    print(f"Processing query: {query}")
    valid_count = 0
    page_number = 1

    while valid_count < 10:
      print(f"Fetching search results, page {page_number}...")
      results = search_with_google_api(query + f"&start={page_number * 10}")

      if not results:
        print("No more results found. Try refining the query.")
        break

      for result in results:
        if valid_count >= 10:
            break  # Stop when 10 valid documents are saved

        title = result["title"]
        link = result["link"]
        snippet = result.get("snippet", "No snippet")

        # Fetch full content of the link
        full_content = fetch_full_content(link)
        if full_content:  # Save only if content is valid
          filename = f"{directory}/doc_{file_count}.txt"
          with open(filename, "w", encoding="utf-8") as f:
            f.write(f"Query: {query}\n")
            f.write(f"Title: {title}\n")
            f.write(f"Link: {link}\n")
            f.write(f"Snippet: {snippet}\n\n")
            f.write(f"Full Content:\n{full_content}")
          print(f"Saved: {filename}")
          valid_count += 1
          file_count += 1
        else:
          print(f"Skipped: {link} (No valid content)")

      page_number += 1  # Move to the next page of results

  print(f"Finished processing all queries. Total files saved: {file_count - 1}")

# %% [markdown]
# # Running this section of Code

# %%
def run_main(input_name, directory_name):
  if not os.path.exists(directory_name):
    queries = gpt_answers(input_name)
    create_dataset_from_queries(queries, directory=directory_name)
  documents = SimpleDirectoryReader(directory_name).load_data()
  return documents

# %%
input_name = "AI-driven drug discovery in antibiotic resistance"
documents = run_main(input_name, "AI_antibiotic_resistance_dataset")

# %% [markdown]
# # Building GraphRAG

# %%
from llama_index.llms.openai import OpenAI

OPENAI_API_KEY = userdata.get('ChatGPT')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
neo_4j = userdata.get('neo_4j')

# Instantiate property_graph_store
graph_store = Neo4jPropertyGraphStore(
    username="neo4j",
    password=neo_4j,
    url="neo4j+s://1a90ca9c.databases.neo4j.io"
)

# %%
index = PropertyGraphIndex.from_documents(  #indices structure the data in intermediate reprezentations that are easy and performant for LLMs to consume.
    documents,
    embed_model = OpenAIEmbedding(model_name="text-embedding-3-small"),
    kg_extractors=[
        SchemaLLMPathExtractor(
            llm=OpenAI(model="gpt-3.5-turbo", temperature=0.0) #Using GPT 3.5 turbo to extract the subject predicate object triples
        )
    ],
    property_graph_store=graph_store,
    show_progress=True,
    use_async=False
)
# Out:
# Parsing nodes:   0%|          | 0/70 [00:00<?, ?it/s]
# Extracting paths from text with schema:   0%|          | 0/834 [00:00<?, ?it/s]
# Extracting paths from text with schema:   0%|          | 1/834 [00:02<33:43,  2.43s/it]
# Extracting paths from text with schema:   0%|          | 2/834 [00:02<15:10,  1.09s/it]
# Extracting paths from text with schema:   0%|          | 3/834 [00:04<22:36,  1.63s/it]
# Extracting paths from text with schema:   0%|          | 4/834 [00:05<15:48,  1.14s/it]
# Extracting paths from text with schema:   1%|          | 5/834 [00:06<17:05,  1.24s/it]
# Extracting paths from text with schema:   1%|          | 6/834 [00:06<12:30,  1.10it/s]
# Extracting paths from text with schema:   1%|          | 7/834 [00:09<19:01,  1.38s/it]
# Extracting paths from text with schema:   1%|          | 8/834 [00:10<19:52,  1.44s/it]
# Extracting paths from text with schema:   1%|          | 9/834 [00:12<21:57,  1.60s/it]
# Extracting paths from text with schema:   1%|          | 10/834 [00:13<17:34,  1.28s/it]
# Extracting paths from text with schema:   1%|▏         | 11/834 [00:14<17:19,  1.26s/it]
# Extracting paths from text with schema:   1%|▏         | 12/834 [00:15<16:06,  1.18s/it]
# Extracting paths from text with schema:   2%|▏         | 13/834 [00:16<16:03,  1.17s/it]
# Extracting paths from text with schema:   2%|▏         | 14/834 [00:18<18:39,  1.36s/it]
# Extracting paths from text with schema:   2%|▏         | 16/834 [00:19<12:51,  1.06it/s]
# Extracting paths from text with schema:   2%|▏         | 17/834 [00:22<20:32,  1.51s/it]
# Extracting paths from text with schema:   2%|▏         | 18/834 [00:22<16:19,  1.20s/it]
# Extracting paths from text with schema:   2%|▏         | 19/834 [00:23<13:11,  1.03it/s]
# Extracting paths from text with schema:   2%|▏         | 20/834 [00:26<21:19,  1.57s/it]
# Extracting paths from text with schema:   3%|▎         | 21/834 [00:27<18:47,  1.39s/it]
# Extracting paths from text with schema:   3%|▎         | 23/834 [00:31<21:57,  1.62s/it]
# Extracting paths from text with schema:   3%|▎         | 24/834 [00:31<16:56,  1.25s/it]
# Extracting paths from text with schema:   3%|▎         | 25/834 [00:31<13:52,  1.03s/it]
# Extracting paths from text with schema:   3%|▎         | 26/834 [00:35<22:59,  1.71s/it]
# Extracting paths from text with schema:   3%|▎         | 27/834 [00:35<17:15,  1.28s/it]
# Extracting paths from text with schema:   3%|▎         | 28/834 [00:39<26:15,  1.95s/it]
# Extracting paths from text with schema:   3%|▎         | 29/834 [00:42<31:22,  2.34s/it]
# Extracting paths from text with schema:   4%|▎         | 30/834 [00:45<35:49,  2.67s/it]
# Extracting paths from text with schema:   4%|▎         | 31/834 [00:50<44:12,  3.30s/it]
# Extracting paths from text with schema:   4%|▍         | 32/834 [00:54<46:13,  3.46s/it]
# Extracting paths from text with schema:   4%|▍         | 33/834 [00:57<45:43,  3.43s/it]
# Extracting paths from text with schema:   4%|▍         | 34/834 [00:58<35:49,  2.69s/it]
# Extracting paths from text with schema:   4%|▍         | 35/834 [01:01<34:42,  2.61s/it]
# Extracting paths from text with schema:   4%|▍         | 36/834 [01:04<37:21,  2.81s/it]
# Extracting paths from text with schema:   4%|▍         | 37/834 [01:06<34:10,  2.57s/it]
# Extracting paths from text with schema:   5%|▍         | 38/834 [01:07<26:50,  2.02s/it]
# Extracting paths from text with schema:   5%|▍         | 39/834 [01:10<30:02,  2.27s/it]
# Extracting paths from text with schema:   5%|▍         | 40/834 [01:10<23:50,  1.80s/it]
# Extracting paths from text with schema:   5%|▍         | 41/834 [01:11<19:52,  1.50s/it]
# Extracting paths from text with schema:   5%|▌         | 42/834 [01:14<24:53,  1.89s/it]
# Extracting paths from text with schema:   5%|▌         | 43/834 [01:15<20:28,  1.55s/it]
# Extracting paths from text with schema:   5%|▌         | 45/834 [01:17<19:31,  1.48s/it]
# Extracting paths from text with schema:   6%|▌         | 46/834 [01:18<17:30,  1.33s/it]
# Extracting paths from text with schema:   6%|▌         | 47/834 [01:23<30:10,  2.30s/it]
# Extracting paths from text with schema:   6%|▌         | 48/834 [01:24<22:26,  1.71s/it]
# Extracting paths from text with schema:   6%|▌         | 49/834 [01:26<23:51,  1.82s/it]
# Extracting paths from text with schema:   6%|▌         | 50/834 [01:26<19:00,  1.45s/it]
# Extracting paths from text with schema:   6%|▌         | 51/834 [01:28<20:31,  1.57s/it]
# Extracting paths from text with schema:   6%|▌         | 52/834 [01:32<28:59,  2.22s/it]
# Extracting paths from text with schema:   6%|▋         | 53/834 [01:36<34:50,  2.68s/it]
# Extracting paths from text with schema:   6%|▋         | 54/834 [01:38<33:48,  2.60s/it]
# Extracting paths from text with schema:   7%|▋         | 55/834 [01:40<30:43,  2.37s/it]
# Extracting paths from text with schema:   7%|▋         | 56/834 [01:45<39:42,  3.06s/it]
# Extracting paths from text with schema:   7%|▋         | 57/834 [01:45<28:52,  2.23s/it]
# Extracting paths from text with schema:   7%|▋         | 58/834 [01:49<37:14,  2.88s/it]
# Extracting paths from text with schema:   7%|▋         | 59/834 [01:50<28:13,  2.18s/it]
# Extracting paths from text with schema:   7%|▋         | 60/834 [01:54<36:46,  2.85s/it]
# Extracting paths from text with schema:   7%|▋         | 61/834 [01:57<35:39,  2.77s/it]
# Extracting paths from text with schema:   7%|▋         | 62/834 [02:01<40:59,  3.19s/it]
# Extracting paths from text with schema:   8%|▊         | 63/834 [02:04<40:19,  3.14s/it]
# Extracting paths from text with schema:   8%|▊         | 64/834 [02:06<36:44,  2.86s/it]
# Extracting paths from text with schema:   8%|▊         | 65/834 [02:13<51:31,  4.02s/it]
# Extracting paths from text with schema:   8%|▊         | 66/834 [02:13<37:39,  2.94s/it]
# Extracting paths from text with schema:   8%|▊         | 67/834 [02:15<34:41,  2.71s/it]
# Extracting paths from text with schema:   8%|▊         | 68/834 [02:17<29:13,  2.29s/it]
# Extracting paths from text with schema:   8%|▊         | 69/834 [02:20<34:14,  2.69s/it]
# Extracting paths from text with schema:   8%|▊         | 70/834 [02:21<28:02,  2.20s/it]
# Extracting paths from text with schema:   9%|▊         | 71/834 [02:24<27:40,  2.18s/it]
# Extracting paths from text with schema:   9%|▊         | 72/834 [02:25<25:32,  2.01s/it]
# Extracting paths from text with schema:   9%|▉         | 73/834 [02:28<30:08,  2.38s/it]
# Extracting paths from text with schema:   9%|▉         | 74/834 [02:30<25:38,  2.02s/it]
# Extracting paths from text with schema:   9%|▉         | 75/834 [02:30<19:27,  1.54s/it]
# Extracting paths from text with schema:   9%|▉         | 76/834 [02:36<34:52,  2.76s/it]
# Extracting paths from text with schema:   9%|▉         | 77/834 [02:36<27:28,  2.18s/it]
# Extracting paths from text with schema:   9%|▉         | 78/834 [02:39<29:12,  2.32s/it]
# Extracting paths from text with schema:   9%|▉         | 79/834 [02:41<26:16,  2.09s/it]
# Extracting paths from text with schema:  10%|▉         | 80/834 [02:44<30:42,  2.44s/it]
# Extracting paths from text with schema:  10%|▉         | 82/834 [02:47<26:32,  2.12s/it]
# Extracting paths from text with schema:  10%|▉         | 83/834 [02:48<22:30,  1.80s/it]
# Extracting paths from text with schema:  10%|█         | 84/834 [02:52<29:47,  2.38s/it]
# Extracting paths from text with schema:  10%|█         | 85/834 [02:53<24:35,  1.97s/it]
# Extracting paths from text with schema:  10%|█         | 86/834 [02:54<22:26,  1.80s/it]
# Extracting paths from text with schema:  10%|█         | 87/834 [02:57<23:59,  1.93s/it]
# Extracting paths from text with schema:  11%|█         | 88/834 [02:59<25:38,  2.06s/it]
# Extracting paths from text with schema:  11%|█         | 89/834 [03:03<31:36,  2.55s/it]
# Extracting paths from text with schema:  11%|█         | 90/834 [03:03<23:25,  1.89s/it]
# Extracting paths from text with schema:  11%|█         | 91/834 [03:04<20:15,  1.64s/it]
# Extracting paths from text with schema:  11%|█         | 92/834 [03:07<24:53,  2.01s/it]
# Extracting paths from text with schema:  11%|█▏        | 94/834 [03:08<15:08,  1.23s/it]
# Extracting paths from text with schema:  11%|█▏        | 95/834 [03:11<22:51,  1.86s/it]
# Extracting paths from text with schema:  12%|█▏        | 96/834 [03:13<23:03,  1.87s/it]
# Extracting paths from text with schema:  12%|█▏        | 97/834 [03:15<21:02,  1.71s/it]
# Extracting paths from text with schema:  12%|█▏        | 98/834 [03:16<18:09,  1.48s/it]
# Extracting paths from text with schema:  12%|█▏        | 99/834 [03:16<15:14,  1.24s/it]
# Extracting paths from text with schema:  12%|█▏        | 100/834 [03:19<19:42,  1.61s/it]
# Extracting paths from text with schema:  12%|█▏        | 101/834 [03:21<21:13,  1.74s/it]
# Extracting paths from text with schema:  12%|█▏        | 103/834 [03:22<16:17,  1.34s/it]
# Extracting paths from text with schema:  12%|█▏        | 104/834 [03:27<25:19,  2.08s/it]
# Extracting paths from text with schema:  13%|█▎        | 105/834 [03:29<24:09,  1.99s/it]
# Extracting paths from text with schema:  13%|█▎        | 106/834 [03:29<18:52,  1.56s/it]
# Extracting paths from text with schema:  13%|█▎        | 107/834 [03:31<20:47,  1.72s/it]
# Extracting paths from text with schema:  13%|█▎        | 108/834 [03:32<17:42,  1.46s/it]
# Extracting paths from text with schema:  13%|█▎        | 109/834 [03:34<19:14,  1.59s/it]
# Extracting paths from text with schema:  13%|█▎        | 110/834 [03:35<16:46,  1.39s/it]
# Extracting paths from text with schema:  13%|█▎        | 111/834 [03:35<13:57,  1.16s/it]
# Extracting paths from text with schema:  13%|█▎        | 112/834 [03:39<23:02,  1.91s/it]
# Extracting paths from text with schema:  14%|█▎        | 113/834 [03:39<16:51,  1.40s/it]
# Extracting paths from text with schema:  14%|█▎        | 114/834 [03:43<25:56,  2.16s/it]
# Extracting paths from text with schema:  14%|█▍        | 115/834 [03:49<39:53,  3.33s/it]
# Extracting paths from text with schema:  14%|█▍        | 116/834 [03:49<28:24,  2.37s/it]
# Extracting paths from text with schema:  14%|█▍        | 117/834 [03:53<32:13,  2.70s/it]
# Extracting paths from text with schema:  14%|█▍        | 118/834 [03:53<24:36,  2.06s/it]
# Extracting paths from text with schema:  14%|█▍        | 119/834 [03:57<31:00,  2.60s/it]
# Extracting paths from text with schema:  14%|█▍        | 120/834 [04:04<44:02,  3.70s/it]
# Extracting paths from text with schema:  15%|█▍        | 121/834 [04:07<43:10,  3.63s/it]
# Extracting paths from text with schema:  15%|█▍        | 122/834 [04:12<47:48,  4.03s/it]
# Extracting paths from text with schema:  15%|█▍        | 123/834 [04:13<36:53,  3.11s/it]
# Extracting paths from text with schema:  15%|█▍        | 124/834 [04:16<36:29,  3.08s/it]
# Extracting paths from text with schema:  15%|█▍        | 125/834 [04:17<28:34,  2.42s/it]
# Extracting paths from text with schema:  15%|█▌        | 126/834 [04:21<32:58,  2.80s/it]
# Extracting paths from text with schema:  15%|█▌        | 127/834 [04:24<36:10,  3.07s/it]
# Extracting paths from text with schema:  15%|█▌        | 128/834 [04:25<26:14,  2.23s/it]
# Extracting paths from text with schema:  15%|█▌        | 129/834 [04:26<22:51,  1.95s/it]
# Extracting paths from text with schema:  16%|█▌        | 130/834 [04:28<22:24,  1.91s/it]
# Extracting paths from text with schema:  16%|█▌        | 131/834 [04:31<27:25,  2.34s/it]
# Extracting paths from text with schema:  16%|█▌        | 132/834 [04:47<1:15:38,  6.46s/it]
# Extracting paths from text with schema:  16%|█▌        | 133/834 [04:52<1:08:33,  5.87s/it]
# Extracting paths from text with schema:  16%|█▌        | 134/834 [04:57<1:05:20,  5.60s/it]
# Extracting paths from text with schema:  16%|█▌        | 135/834 [05:00<56:42,  4.87s/it]
# Extracting paths from text with schema:  16%|█▋        | 136/834 [05:02<47:55,  4.12s/it]
# Extracting paths from text with schema:  16%|█▋        | 137/834 [05:04<39:50,  3.43s/it]
# Extracting paths from text with schema:  17%|█▋        | 138/834 [05:06<35:06,  3.03s/it]
# Extracting paths from text with schema:  17%|█▋        | 139/834 [05:07<29:18,  2.53s/it]
# Extracting paths from text with schema:  17%|█▋        | 140/834 [05:10<28:35,  2.47s/it]
# Extracting paths from text with schema:  17%|█▋        | 141/834 [05:13<32:45,  2.84s/it]
# Extracting paths from text with schema:  17%|█▋        | 142/834 [05:17<36:29,  3.16s/it]
# Extracting paths from text with schema:  17%|█▋        | 143/834 [05:18<27:21,  2.38s/it]
# Extracting paths from text with schema:  17%|█▋        | 144/834 [05:21<30:15,  2.63s/it]
# Extracting paths from text with schema:  17%|█▋        | 145/834 [05:23<27:32,  2.40s/it]
# Extracting paths from text with schema:  18%|█▊        | 146/834 [05:23<20:33,  1.79s/it]
# Extracting paths from text with schema:  18%|█▊        | 147/834 [05:28<31:08,  2.72s/it]
# Extracting paths from text with schema:  18%|█▊        | 148/834 [05:29<23:18,  2.04s/it]
# Extracting paths from text with schema:  18%|█▊        | 149/834 [05:32<27:54,  2.44s/it]
# Extracting paths from text with schema:  18%|█▊        | 150/834 [05:33<21:52,  1.92s/it]
# Extracting paths from text with schema:  18%|█▊        | 151/834 [05:33<16:50,  1.48s/it]
# Extracting paths from text with schema:  18%|█▊        | 152/834 [05:37<23:30,  2.07s/it]
# Extracting paths from text with schema:  18%|█▊        | 153/834 [05:44<40:32,  3.57s/it]
# Extracting paths from text with schema:  18%|█▊        | 154/834 [05:46<36:29,  3.22s/it]
# Extracting paths from text with schema:  19%|█▊        | 155/834 [05:47<30:20,  2.68s/it]
# Extracting paths from text with schema:  19%|█▊        | 156/834 [05:49<27:49,  2.46s/it]
# Extracting paths from text with schema:  19%|█▉        | 157/834 [05:52<28:52,  2.56s/it]
# Extracting paths from text with schema:  19%|█▉        | 158/834 [05:55<28:26,  2.52s/it]
# Extracting paths from text with schema:  19%|█▉        | 159/834 [05:56<25:31,  2.27s/it]
# Extracting paths from text with schema:  19%|█▉        | 160/834 [05:58<24:52,  2.21s/it]
# Extracting paths from text with schema:  19%|█▉        | 161/834 [06:01<26:52,  2.40s/it]
# Extracting paths from text with schema:  19%|█▉        | 162/834 [06:03<23:45,  2.12s/it]
# Extracting paths from text with schema:  20%|█▉        | 163/834 [06:05<23:05,  2.06s/it]
# Extracting paths from text with schema:  20%|█▉        | 164/834 [06:07<22:54,  2.05s/it]
# Extracting paths from text with schema:  20%|█▉        | 165/834 [06:08<21:41,  1.94s/it]
# Extracting paths from text with schema:  20%|█▉        | 166/834 [06:27<1:16:11,  6.84s/it]
# Extracting paths from text with schema:  20%|██        | 167/834 [06:28<57:16,  5.15s/it]
# Extracting paths from text with schema:  20%|██        | 168/834 [06:30<46:10,  4.16s/it]
# Extracting paths from text with schema:  20%|██        | 169/834 [06:32<38:24,  3.47s/it]
# Extracting paths from text with schema:  20%|██        | 170/834 [06:34<33:39,  3.04s/it]
# Extracting paths from text with schema:  21%|██        | 171/834 [06:36<31:19,  2.84s/it]
# Extracting paths from text with schema:  21%|██        | 172/834 [06:38<27:43,  2.51s/it]
# Extracting paths from text with schema:  21%|██        | 173/834 [06:39<22:23,  2.03s/it]
# Extracting paths from text with schema:  21%|██        | 174/834 [06:41<24:08,  2.19s/it]
# Extracting paths from text with schema:  21%|██        | 175/834 [06:42<20:46,  1.89s/it]
# Extracting paths from text with schema:  21%|██        | 176/834 [06:46<25:48,  2.35s/it]
# Extracting paths from text with schema:  21%|██        | 177/834 [06:50<31:54,  2.91s/it]
# Extracting paths from text with schema:  21%|██▏       | 178/834 [06:50<22:58,  2.10s/it]
# Extracting paths from text with schema:  21%|██▏       | 179/834 [06:55<30:09,  2.76s/it]
# Extracting paths from text with schema:  22%|██▏       | 180/834 [06:55<23:53,  2.19s/it]
# Extracting paths from text with schema:  22%|██▏       | 181/834 [07:01<36:11,  3.33s/it]
# Extracting paths from text with schema:  22%|██▏       | 182/834 [07:06<39:30,  3.64s/it]
# Extracting paths from text with schema:  22%|██▏       | 183/834 [07:09<39:06,  3.60s/it]
# Extracting paths from text with schema:  22%|██▏       | 184/834 [07:12<36:29,  3.37s/it]
# Extracting paths from text with schema:  22%|██▏       | 185/834 [07:16<37:15,  3.44s/it]
# Extracting paths from text with schema:  22%|██▏       | 186/834 [07:16<26:30,  2.45s/it]
# Extracting paths from text with schema:  22%|██▏       | 187/834 [07:18<26:00,  2.41s/it]
# Extracting paths from text with schema:  23%|██▎       | 188/834 [07:20<22:33,  2.10s/it]
# Extracting paths from text with schema:  23%|██▎       | 189/834 [07:20<17:48,  1.66s/it]
# Extracting paths from text with schema:  23%|██▎       | 190/834 [07:23<22:15,  2.07s/it]
# Extracting paths from text with schema:  23%|██▎       | 191/834 [07:26<23:19,  2.18s/it]
# Extracting paths from text with schema:  23%|██▎       | 192/834 [07:26<16:45,  1.57s/it]
# Extracting paths from text with schema:  23%|██▎       | 193/834 [07:29<22:53,  2.14s/it]
# Extracting paths from text with schema:  23%|██▎       | 194/834 [07:34<30:53,  2.90s/it]
# Extracting paths from text with schema:  23%|██▎       | 195/834 [07:34<23:06,  2.17s/it]
# Extracting paths from text with schema:  24%|██▎       | 196/834 [07:37<25:04,  2.36s/it]
# Extracting paths from text with schema:  24%|██▎       | 197/834 [07:43<37:03,  3.49s/it]
# Extracting paths from text with schema:  24%|██▎       | 198/834 [07:47<37:32,  3.54s/it]
# Extracting paths from text with schema:  24%|██▍       | 199/834 [07:51<38:52,  3.67s/it]
# Extracting paths from text with schema:  24%|██▍       | 200/834 [07:53<33:45,  3.19s/it]
# Extracting paths from text with schema:  24%|██▍       | 201/834 [07:55<29:04,  2.76s/it]
# Extracting paths from text with schema:  24%|██▍       | 202/834 [07:57<28:48,  2.73s/it]
# Extracting paths from text with schema:  24%|██▍       | 203/834 [08:00<28:06,  2.67s/it]
# Extracting paths from text with schema:  24%|██▍       | 204/834 [08:03<29:46,  2.84s/it]
# Extracting paths from text with schema:  25%|██▍       | 205/834 [08:04<22:41,  2.16s/it]
# Extracting paths from text with schema:  25%|██▍       | 206/834 [08:04<17:38,  1.69s/it]
# Extracting paths from text with schema:  25%|██▍       | 207/834 [08:09<25:45,  2.46s/it]
# Extracting paths from text with schema:  25%|██▍       | 208/834 [08:09<20:33,  1.97s/it]
# Extracting paths from text with schema:  25%|██▌       | 209/834 [08:13<25:44,  2.47s/it]
# Extracting paths from text with schema:  25%|██▌       | 210/834 [08:21<43:21,  4.17s/it]
# Extracting paths from text with schema:  25%|██▌       | 211/834 [08:24<40:16,  3.88s/it]
# Extracting paths from text with schema:  25%|██▌       | 212/834 [08:26<33:35,  3.24s/it]
# Extracting paths from text with schema:  26%|██▌       | 213/834 [08:31<39:17,  3.80s/it]
# Extracting paths from text with schema:  26%|██▌       | 214/834 [08:32<29:16,  2.83s/it]
# Extracting paths from text with schema:  26%|██▌       | 215/834 [08:38<40:41,  3.94s/it]
# Extracting paths from text with schema:  26%|██▌       | 216/834 [08:39<31:40,  3.08s/it]
# Extracting paths from text with schema:  26%|██▌       | 217/834 [08:42<29:46,  2.90s/it]
# Extracting paths from text with schema:  26%|██▌       | 218/834 [08:44<25:50,  2.52s/it]
# Extracting paths from text with schema:  26%|██▋       | 219/834 [08:45<22:47,  2.22s/it]
# Extracting paths from text with schema:  26%|██▋       | 221/834 [08:47<16:09,  1.58s/it]
# Extracting paths from text with schema:  27%|██▋       | 222/834 [08:49<17:05,  1.68s/it]
# Extracting paths from text with schema:  27%|██▋       | 223/834 [08:50<15:49,  1.55s/it]
# Extracting paths from text with schema:  27%|██▋       | 224/834 [08:52<17:41,  1.74s/it]
# Extracting paths from text with schema:  27%|██▋       | 225/834 [08:53<14:09,  1.39s/it]
# Extracting paths from text with schema:  27%|██▋       | 226/834 [08:54<12:51,  1.27s/it]
# Extracting paths from text with schema:  27%|██▋       | 227/834 [08:55<14:38,  1.45s/it]
# Extracting paths from text with schema:  27%|██▋       | 228/834 [08:58<17:34,  1.74s/it]
# Extracting paths from text with schema:  27%|██▋       | 229/834 [08:59<14:42,  1.46s/it]
# Extracting paths from text with schema:  28%|██▊       | 230/834 [09:01<18:22,  1.83s/it]
# Extracting paths from text with schema:  28%|██▊       | 231/834 [09:03<16:25,  1.63s/it]
# Extracting paths from text with schema:  28%|██▊       | 232/834 [09:06<21:17,  2.12s/it]
# Extracting paths from text with schema:  28%|██▊       | 233/834 [09:06<15:57,  1.59s/it]
# Extracting paths from text with schema:  28%|██▊       | 234/834 [09:10<23:49,  2.38s/it]
# Extracting paths from text with schema:  28%|██▊       | 235/834 [09:11<18:04,  1.81s/it]
# Extracting paths from text with schema:  28%|██▊       | 236/834 [09:12<15:19,  1.54s/it]
# Extracting paths from text with schema:  28%|██▊       | 237/834 [09:14<17:29,  1.76s/it]
# Extracting paths from text with schema:  29%|██▊       | 238/834 [09:15<15:53,  1.60s/it]
# Extracting paths from text with schema:  29%|██▊       | 239/834 [09:18<18:41,  1.88s/it]
# Extracting paths from text with schema:  29%|██▉       | 240/834 [09:19<16:26,  1.66s/it]
# Extracting paths from text with schema:  29%|██▉       | 242/834 [09:23<17:58,  1.82s/it]
# Extracting paths from text with schema:  29%|██▉       | 243/834 [09:23<13:52,  1.41s/it]
# Extracting paths from text with schema:  29%|██▉       | 244/834 [09:24<12:56,  1.32s/it]
# Extracting paths from text with schema:  29%|██▉       | 245/834 [09:27<16:30,  1.68s/it]
# Extracting paths from text with schema:  29%|██▉       | 246/834 [09:28<14:41,  1.50s/it]
# Extracting paths from text with schema:  30%|██▉       | 248/834 [09:31<14:29,  1.48s/it]
# Extracting paths from text with schema:  30%|██▉       | 249/834 [09:33<16:53,  1.73s/it]
# Extracting paths from text with schema:  30%|██▉       | 250/834 [09:34<15:11,  1.56s/it]
# Extracting paths from text with schema:  30%|███       | 251/834 [09:38<20:05,  2.07s/it]
# Extracting paths from text with schema:  30%|███       | 252/834 [09:38<15:33,  1.60s/it]
# Extracting paths from text with schema:  30%|███       | 253/834 [09:54<53:01,  5.48s/it]
# Extracting paths from text with schema:  30%|███       | 254/834 [09:58<50:53,  5.27s/it]
# Extracting paths from text with schema:  31%|███       | 255/834 [09:59<38:58,  4.04s/it]
# Extracting paths from text with schema:  31%|███       | 256/834 [10:03<36:41,  3.81s/it]
# Extracting paths from text with schema:  31%|███       | 258/834 [10:05<24:16,  2.53s/it]
# Extracting paths from text with schema:  31%|███       | 259/834 [10:07<24:12,  2.53s/it]
# Extracting paths from text with schema:  31%|███       | 260/834 [10:10<25:36,  2.68s/it]
# Extracting paths from text with schema:  31%|███▏      | 261/834 [10:18<38:51,  4.07s/it]
# Extracting paths from text with schema:  31%|███▏      | 262/834 [10:23<40:21,  4.23s/it]
# Extracting paths from text with schema:  32%|███▏      | 263/834 [10:27<40:09,  4.22s/it]
# Extracting paths from text with schema:  32%|███▏      | 264/834 [10:32<41:08,  4.33s/it]
# Extracting paths from text with schema:  32%|███▏      | 265/834 [10:38<47:43,  5.03s/it]
# Extracting paths from text with schema:  32%|███▏      | 266/834 [10:39<34:47,  3.68s/it]
# Extracting paths from text with schema:  32%|███▏      | 267/834 [10:44<39:56,  4.23s/it]
# Extracting paths from text with schema:  32%|███▏      | 268/834 [10:46<33:39,  3.57s/it]
# Extracting paths from text with schema:  32%|███▏      | 269/834 [10:49<30:21,  3.22s/it]
# Extracting paths from text with schema:  32%|███▏      | 270/834 [10:51<27:57,  2.97s/it]
# Extracting paths from text with schema:  32%|███▏      | 271/834 [10:52<22:53,  2.44s/it]
# Extracting paths from text with schema:  33%|███▎      | 272/834 [10:56<25:46,  2.75s/it]
# Extracting paths from text with schema:  33%|███▎      | 273/834 [10:56<19:06,  2.04s/it]
# Extracting paths from text with schema:  33%|███▎      | 274/834 [10:59<22:32,  2.42s/it]
# Extracting paths from text with schema:  33%|███▎      | 275/834 [11:01<21:21,  2.29s/it]
# Extracting paths from text with schema:  33%|███▎      | 276/834 [11:03<19:34,  2.11s/it]
# Extracting paths from text with schema:  33%|███▎      | 277/834 [11:06<21:28,  2.31s/it]
# Extracting paths from text with schema:  33%|███▎      | 278/834 [11:07<18:02,  1.95s/it]
# Extracting paths from text with schema:  33%|███▎      | 279/834 [11:11<22:51,  2.47s/it]
# Extracting paths from text with schema:  34%|███▎      | 280/834 [11:11<16:58,  1.84s/it]
# Extracting paths from text with schema:  34%|███▎      | 281/834 [11:12<15:42,  1.70s/it]
# Extracting paths from text with schema:  34%|███▍      | 282/834 [11:14<16:34,  1.80s/it]
# Extracting paths from text with schema:  34%|███▍      | 283/834 [11:16<16:46,  1.83s/it]
# Extracting paths from text with schema:  34%|███▍      | 284/834 [11:17<12:42,  1.39s/it]
# Extracting paths from text with schema:  34%|███▍      | 285/834 [11:21<19:42,  2.15s/it]
# Extracting paths from text with schema:  34%|███▍      | 287/834 [11:21<11:24,  1.25s/it]
# Extracting paths from text with schema:  35%|███▍      | 288/834 [11:21<09:37,  1.06s/it]
# Extracting paths from text with schema:  35%|███▍      | 289/834 [11:25<16:20,  1.80s/it]
# Extracting paths from text with schema:  35%|███▍      | 291/834 [11:26<11:29,  1.27s/it]
# Extracting paths from text with schema:  35%|███▌      | 292/834 [11:29<15:02,  1.66s/it]
# Extracting paths from text with schema:  35%|███▌      | 293/834 [11:30<11:48,  1.31s/it]
# Extracting paths from text with schema:  35%|███▌      | 294/834 [11:30<09:58,  1.11s/it]
# Extracting paths from text with schema:  35%|███▌      | 295/834 [11:31<08:44,  1.03it/s]
# Extracting paths from text with schema:  35%|███▌      | 296/834 [11:33<12:24,  1.38s/it]
# Extracting paths from text with schema:  36%|███▌      | 297/834 [11:34<11:04,  1.24s/it]
# Extracting paths from text with schema:  36%|███▌      | 298/834 [11:36<11:33,  1.29s/it]
# Extracting paths from text with schema:  36%|███▌      | 299/834 [11:36<09:33,  1.07s/it]
# Extracting paths from text with schema:  36%|███▌      | 300/834 [11:38<11:04,  1.24s/it]
# Extracting paths from text with schema:  36%|███▌      | 301/834 [11:39<10:27,  1.18s/it]
# Extracting paths from text with schema:  36%|███▌      | 302/834 [11:39<08:45,  1.01it/s]
# Extracting paths from text with schema:  36%|███▋      | 303/834 [11:42<12:26,  1.41s/it]
# Extracting paths from text with schema:  36%|███▋      | 304/834 [11:47<21:30,  2.43s/it]
# Extracting paths from text with schema:  37%|███▋      | 305/834 [11:50<24:28,  2.78s/it]
# Extracting paths from text with schema:  37%|███▋      | 306/834 [11:54<26:39,  3.03s/it]
# Extracting paths from text with schema:  37%|███▋      | 307/834 [11:59<31:58,  3.64s/it]
# Extracting paths from text with schema:  37%|███▋      | 308/834 [11:59<22:45,  2.60s/it]
# Extracting paths from text with schema:  37%|███▋      | 309/834 [12:00<17:53,  2.05s/it]
# Extracting paths from text with schema:  37%|███▋      | 310/834 [12:02<18:28,  2.11s/it]
# Extracting paths from text with schema:  37%|███▋      | 311/834 [12:03<15:41,  1.80s/it]
# Extracting paths from text with schema:  37%|███▋      | 312/834 [12:07<20:31,  2.36s/it]
# Extracting paths from text with schema:  38%|███▊      | 313/834 [12:08<17:19,  2.00s/it]
# Extracting paths from text with schema:  38%|███▊      | 314/834 [12:11<19:44,  2.28s/it]
# Extracting paths from text with schema:  38%|███▊      | 315/834 [12:12<18:01,  2.08s/it]
# Extracting paths from text with schema:  38%|███▊      | 316/834 [12:15<18:46,  2.17s/it]
# Extracting paths from text with schema:  38%|███▊      | 317/834 [12:17<19:42,  2.29s/it]
# Extracting paths from text with schema:  38%|███▊      | 318/834 [12:19<16:35,  1.93s/it]
# Extracting paths from text with schema:  38%|███▊      | 319/834 [12:19<13:02,  1.52s/it]
# Extracting paths from text with schema:  38%|███▊      | 320/834 [12:20<10:47,  1.26s/it]
# Extracting paths from text with schema:  38%|███▊      | 321/834 [12:21<10:19,  1.21s/it]
# Extracting paths from text with schema:  39%|███▊      | 322/834 [12:22<11:00,  1.29s/it]
# Extracting paths from text with schema:  39%|███▊      | 323/834 [12:25<14:05,  1.65s/it]
# Extracting paths from text with schema:  39%|███▉      | 324/834 [12:25<11:09,  1.31s/it]
# Extracting paths from text with schema:  39%|███▉      | 325/834 [12:26<10:16,  1.21s/it]
# Extracting paths from text with schema:  39%|███▉      | 326/834 [12:27<10:05,  1.19s/it]
# Extracting paths from text with schema:  39%|███▉      | 327/834 [12:30<14:26,  1.71s/it]
# Extracting paths from text with schema:  39%|███▉      | 328/834 [12:31<12:52,  1.53s/it]
# Extracting paths from text with schema:  39%|███▉      | 329/834 [12:40<30:04,  3.57s/it]
# Extracting paths from text with schema:  40%|███▉      | 330/834 [12:44<32:33,  3.88s/it]
# Extracting paths from text with schema:  40%|███▉      | 331/834 [12:54<47:26,  5.66s/it]
# Extracting paths from text with schema:  40%|███▉      | 332/834 [12:59<45:13,  5.41s/it]
# Extracting paths from text with schema:  40%|███▉      | 333/834 [13:04<43:06,  5.16s/it]
# Extracting paths from text with schema:  40%|████      | 334/834 [13:06<36:43,  4.41s/it]
# Extracting paths from text with schema:  40%|████      | 335/834 [13:08<29:54,  3.60s/it]
# Extracting paths from text with schema:  40%|████      | 336/834 [13:10<24:57,  3.01s/it]
# Extracting paths from text with schema:  40%|████      | 337/834 [13:14<29:00,  3.50s/it]
# Extracting paths from text with schema:  41%|████      | 339/834 [13:21<27:54,  3.38s/it]
# Extracting paths from text with schema:  41%|████      | 340/834 [13:21<21:54,  2.66s/it]
# Extracting paths from text with schema:  41%|████      | 341/834 [13:24<22:59,  2.80s/it]
# Extracting paths from text with schema:  41%|████      | 342/834 [13:25<18:57,  2.31s/it]
# Extracting paths from text with schema:  41%|████      | 343/834 [13:26<14:08,  1.73s/it]
# Extracting paths from text with schema:  41%|████      | 344/834 [13:28<15:45,  1.93s/it]
# Extracting paths from text with schema:  41%|████▏     | 345/834 [13:29<14:22,  1.76s/it]
# Extracting paths from text with schema:  41%|████▏     | 346/834 [13:30<10:23,  1.28s/it]
# Extracting paths from text with schema:  42%|████▏     | 347/834 [13:30<07:52,  1.03it/s]
# Extracting paths from text with schema:  42%|████▏     | 348/834 [13:32<10:00,  1.24s/it]
# Extracting paths from text with schema:  42%|████▏     | 349/834 [13:34<12:15,  1.52s/it]
# Extracting paths from text with schema:  42%|████▏     | 350/834 [13:34<09:41,  1.20s/it]
# Extracting paths from text with schema:  42%|████▏     | 351/834 [13:35<08:57,  1.11s/it]
# Extracting paths from text with schema:  42%|████▏     | 352/834 [13:35<06:35,  1.22it/s]
# Extracting paths from text with schema:  42%|████▏     | 353/834 [13:38<10:40,  1.33s/it]
# Extracting paths from text with schema:  42%|████▏     | 354/834 [13:38<08:30,  1.06s/it]
# Extracting paths from text with schema:  43%|████▎     | 355/834 [13:41<11:39,  1.46s/it]
# Extracting paths from text with schema:  43%|████▎     | 356/834 [13:41<09:46,  1.23s/it]
# Extracting paths from text with schema:  43%|████▎     | 357/834 [13:42<08:47,  1.11s/it]
# Extracting paths from text with schema:  43%|████▎     | 358/834 [13:44<11:35,  1.46s/it]
# Extracting paths from text with schema:  43%|████▎     | 359/834 [13:45<10:15,  1.29s/it]
# Extracting paths from text with schema:  43%|████▎     | 361/834 [13:48<10:24,  1.32s/it]
# Extracting paths from text with schema:  43%|████▎     | 362/834 [13:49<09:45,  1.24s/it]
# Extracting paths from text with schema:  44%|████▎     | 363/834 [13:50<08:25,  1.07s/it]
# Extracting paths from text with schema:  44%|████▎     | 364/834 [13:50<07:10,  1.09it/s]
# Extracting paths from text with schema:  44%|████▍     | 365/834 [13:53<10:54,  1.39s/it]
# Extracting paths from text with schema:  44%|████▍     | 366/834 [13:54<09:52,  1.27s/it]
# Extracting paths from text with schema:  44%|████▍     | 368/834 [13:57<10:58,  1.41s/it]
# Extracting paths from text with schema:  44%|████▍     | 369/834 [13:57<08:38,  1.12s/it]
# Extracting paths from text with schema:  44%|████▍     | 370/834 [13:58<08:46,  1.13s/it]
# Extracting paths from text with schema:  44%|████▍     | 371/834 [13:59<08:29,  1.10s/it]
# Extracting paths from text with schema:  45%|████▍     | 372/834 [14:01<09:31,  1.24s/it]
# Extracting paths from text with schema:  45%|████▍     | 373/834 [14:01<07:17,  1.05it/s]
# Extracting paths from text with schema:  45%|████▍     | 374/834 [14:02<07:06,  1.08it/s]
# Extracting paths from text with schema:  45%|████▍     | 375/834 [14:05<11:12,  1.46s/it]
# Extracting paths from text with schema:  45%|████▌     | 376/834 [14:06<10:08,  1.33s/it]
# Extracting paths from text with schema:  45%|████▌     | 377/834 [14:06<08:13,  1.08s/it]
# Extracting paths from text with schema:  45%|████▌     | 378/834 [14:08<09:10,  1.21s/it]
# Extracting paths from text with schema:  45%|████▌     | 379/834 [14:08<06:46,  1.12it/s]
# Extracting paths from text with schema:  46%|████▌     | 380/834 [14:11<11:22,  1.50s/it]
# Extracting paths from text with schema:  46%|████▌     | 381/834 [14:11<08:19,  1.10s/it]
# Extracting paths from text with schema:  46%|████▌     | 382/834 [14:12<06:58,  1.08it/s]
# Extracting paths from text with schema:  46%|████▌     | 383/834 [14:12<05:21,  1.40it/s]
# Extracting paths from text with schema:  46%|████▌     | 384/834 [14:15<10:53,  1.45s/it]
# Extracting paths from text with schema:  46%|████▌     | 385/834 [14:15<08:21,  1.12s/it]
# Extracting paths from text with schema:  46%|████▋     | 386/834 [14:16<07:28,  1.00s/it]
# Extracting paths from text with schema:  46%|████▋     | 387/834 [14:18<09:49,  1.32s/it]
# Extracting paths from text with schema:  47%|████▋     | 388/834 [14:19<09:15,  1.25s/it]
# Extracting paths from text with schema:  47%|████▋     | 389/834 [14:20<07:35,  1.02s/it]
# Extracting paths from text with schema:  47%|████▋     | 390/834 [14:25<16:36,  2.24s/it]
# Extracting paths from text with schema:  47%|████▋     | 391/834 [14:27<16:30,  2.24s/it]
# Extracting paths from text with schema:  47%|████▋     | 392/834 [14:31<20:36,  2.80s/it]
# Extracting paths from text with schema:  47%|████▋     | 393/834 [14:31<14:51,  2.02s/it]
# Extracting paths from text with schema:  47%|████▋     | 394/834 [14:35<19:03,  2.60s/it]
# Extracting paths from text with schema:  47%|████▋     | 395/834 [14:36<15:39,  2.14s/it]
# Extracting paths from text with schema:  47%|████▋     | 396/834 [14:39<16:08,  2.21s/it]
# Extracting paths from text with schema:  48%|████▊     | 397/834 [14:41<15:39,  2.15s/it]
# Extracting paths from text with schema:  48%|████▊     | 398/834 [14:42<12:56,  1.78s/it]
# Extracting paths from text with schema:  48%|████▊     | 399/834 [14:45<15:27,  2.13s/it]
# Extracting paths from text with schema:  48%|████▊     | 400/834 [14:49<20:52,  2.89s/it]
# Extracting paths from text with schema:  48%|████▊     | 401/834 [14:52<21:02,  2.92s/it]
# Extracting paths from text with schema:  48%|████▊     | 402/834 [14:55<20:56,  2.91s/it]
# Extracting paths from text with schema:  48%|████▊     | 403/834 [14:55<14:59,  2.09s/it]
# Extracting paths from text with schema:  48%|████▊     | 404/834 [15:00<21:11,  2.96s/it]
# Extracting paths from text with schema:  49%|████▊     | 405/834 [15:05<24:42,  3.46s/it]
# Extracting paths from text with schema:  49%|████▊     | 406/834 [15:10<28:29,  3.99s/it]
# Extracting paths from text with schema:  49%|████▉     | 407/834 [15:14<28:11,  3.96s/it]
# Extracting paths from text with schema:  49%|████▉     | 408/834 [15:15<21:32,  3.03s/it]
# Extracting paths from text with schema:  49%|████▉     | 409/834 [15:17<19:21,  2.73s/it]
# Extracting paths from text with schema:  49%|████▉     | 410/834 [15:19<18:30,  2.62s/it]
# Extracting paths from text with schema:  49%|████▉     | 411/834 [15:20<13:45,  1.95s/it]
# Extracting paths from text with schema:  49%|████▉     | 412/834 [15:21<13:29,  1.92s/it]
# Extracting paths from text with schema:  50%|████▉     | 413/834 [15:23<11:38,  1.66s/it]
# Extracting paths from text with schema:  50%|████▉     | 414/834 [15:26<15:37,  2.23s/it]
# Extracting paths from text with schema:  50%|████▉     | 415/834 [15:27<12:38,  1.81s/it]
# Extracting paths from text with schema:  50%|████▉     | 416/834 [15:29<14:12,  2.04s/it]
# Extracting paths from text with schema:  50%|█████     | 417/834 [15:32<15:11,  2.19s/it]
# Extracting paths from text with schema:  50%|█████     | 418/834 [15:33<13:04,  1.89s/it]
# Extracting paths from text with schema:  50%|█████     | 419/834 [15:33<09:43,  1.41s/it]
# Extracting paths from text with schema:  50%|█████     | 420/834 [15:35<09:35,  1.39s/it]
# Extracting paths from text with schema:  50%|█████     | 421/834 [15:36<09:09,  1.33s/it]
# Extracting paths from text with schema:  51%|█████     | 422/834 [15:39<11:52,  1.73s/it]
# Extracting paths from text with schema:  51%|█████     | 423/834 [15:40<10:04,  1.47s/it]
# Extracting paths from text with schema:  51%|█████     | 424/834 [15:42<12:50,  1.88s/it]
# Extracting paths from text with schema:  51%|█████     | 425/834 [15:44<11:36,  1.70s/it]
# Extracting paths from text with schema:  51%|█████     | 426/834 [15:45<11:47,  1.73s/it]
# Extracting paths from text with schema:  51%|█████     | 427/834 [15:48<12:37,  1.86s/it]
# Extracting paths from text with schema:  51%|█████▏    | 428/834 [15:53<20:34,  3.04s/it]
# Extracting paths from text with schema:  51%|█████▏    | 429/834 [15:57<21:50,  3.23s/it]
# Extracting paths from text with schema:  52%|█████▏    | 430/834 [15:58<16:42,  2.48s/it]
# Extracting paths from text with schema:  52%|█████▏    | 431/834 [15:59<14:11,  2.11s/it]
# Extracting paths from text with schema:  52%|█████▏    | 432/834 [16:00<12:40,  1.89s/it]
# Extracting paths from text with schema:  52%|█████▏    | 433/834 [16:01<10:06,  1.51s/it]
# Extracting paths from text with schema:  52%|█████▏    | 434/834 [16:03<10:21,  1.55s/it]
# Extracting paths from text with schema:  52%|█████▏    | 435/834 [16:05<11:41,  1.76s/it]
# Extracting paths from text with schema:  52%|█████▏    | 437/834 [16:07<09:10,  1.39s/it]
# Extracting paths from text with schema:  53%|█████▎    | 438/834 [16:10<11:37,  1.76s/it]
# Extracting paths from text with schema:  53%|█████▎    | 439/834 [16:12<11:54,  1.81s/it]
# Extracting paths from text with schema:  53%|█████▎    | 440/834 [16:13<11:45,  1.79s/it]
# Extracting paths from text with schema:  53%|█████▎    | 441/834 [16:16<13:19,  2.03s/it]
# Extracting paths from text with schema:  53%|█████▎    | 442/834 [16:18<13:28,  2.06s/it]
# Extracting paths from text with schema:  53%|█████▎    | 443/834 [16:21<14:42,  2.26s/it]
# Extracting paths from text with schema:  53%|█████▎    | 444/834 [16:22<12:47,  1.97s/it]
# Extracting paths from text with schema:  53%|█████▎    | 445/834 [16:25<13:51,  2.14s/it]
# Extracting paths from text with schema:  53%|█████▎    | 446/834 [16:26<11:45,  1.82s/it]
# Extracting paths from text with schema:  54%|█████▎    | 447/834 [16:28<13:05,  2.03s/it]
# Extracting paths from text with schema:  54%|█████▎    | 448/834 [16:30<11:59,  1.86s/it]
# Extracting paths from text with schema:  54%|█████▍    | 449/834 [16:35<18:37,  2.90s/it]
# Extracting paths from text with schema:  54%|█████▍    | 450/834 [16:39<21:11,  3.31s/it]
# Extracting paths from text with schema:  54%|█████▍    | 451/834 [16:44<22:55,  3.59s/it]
# Extracting paths from text with schema:  54%|█████▍    | 452/834 [16:48<24:10,  3.80s/it]
# Extracting paths from text with schema:  54%|█████▍    | 454/834 [16:52<18:58,  3.00s/it]
# Extracting paths from text with schema:  55%|█████▍    | 455/834 [16:54<16:44,  2.65s/it]
# Extracting paths from text with schema:  55%|█████▍    | 456/834 [16:56<15:40,  2.49s/it]
# Extracting paths from text with schema:  55%|█████▍    | 457/834 [16:56<11:55,  1.90s/it]
# Extracting paths from text with schema:  55%|█████▍    | 458/834 [16:58<12:00,  1.92s/it]
# Extracting paths from text with schema:  55%|█████▌    | 459/834 [17:01<13:56,  2.23s/it]
# Extracting paths from text with schema:  55%|█████▌    | 460/834 [17:01<10:22,  1.67s/it]
# Extracting paths from text with schema:  55%|█████▌    | 461/834 [17:06<14:57,  2.41s/it]
# Extracting paths from text with schema:  55%|█████▌    | 462/834 [17:06<12:07,  1.96s/it]
# Extracting paths from text with schema:  56%|█████▌    | 463/834 [17:08<11:40,  1.89s/it]
# Extracting paths from text with schema:  56%|█████▌    | 464/834 [17:10<11:37,  1.88s/it]
# Extracting paths from text with schema:  56%|█████▌    | 465/834 [17:14<15:58,  2.60s/it]
# Extracting paths from text with schema:  56%|█████▌    | 466/834 [17:15<13:19,  2.17s/it]
# Extracting paths from text with schema:  56%|█████▌    | 467/834 [17:26<28:18,  4.63s/it]
# Extracting paths from text with schema:  56%|█████▌    | 468/834 [17:29<24:52,  4.08s/it]
# Extracting paths from text with schema:  56%|█████▌    | 469/834 [17:31<21:45,  3.58s/it]
# Extracting paths from text with schema:  56%|█████▋    | 470/834 [17:35<21:42,  3.58s/it]
# Extracting paths from text with schema:  57%|█████▋    | 472/834 [17:46<27:35,  4.57s/it]
# Extracting paths from text with schema:  57%|█████▋    | 473/834 [17:50<26:35,  4.42s/it]
# Extracting paths from text with schema:  57%|█████▋    | 474/834 [17:50<20:12,  3.37s/it]
# Extracting paths from text with schema:  57%|█████▋    | 475/834 [17:52<17:06,  2.86s/it]
# Extracting paths from text with schema:  57%|█████▋    | 476/834 [17:54<15:09,  2.54s/it]
# Extracting paths from text with schema:  57%|█████▋    | 477/834 [17:57<16:09,  2.72s/it]
# Extracting paths from text with schema:  57%|█████▋    | 478/834 [18:01<18:21,  3.09s/it]
# Extracting paths from text with schema:  57%|█████▋    | 479/834 [18:04<19:00,  3.21s/it]
# Extracting paths from text with schema:  58%|█████▊    | 480/834 [18:06<17:03,  2.89s/it]
# Extracting paths from text with schema:  58%|█████▊    | 481/834 [18:10<17:22,  2.95s/it]
# Extracting paths from text with schema:  58%|█████▊    | 482/834 [18:14<20:35,  3.51s/it]
# Extracting paths from text with schema:  58%|█████▊    | 483/834 [18:21<26:25,  4.52s/it]
# Extracting paths from text with schema:  58%|█████▊    | 484/834 [18:23<20:49,  3.57s/it]
# Extracting paths from text with schema:  58%|█████▊    | 485/834 [18:24<16:08,  2.78s/it]
# Extracting paths from text with schema:  58%|█████▊    | 486/834 [18:30<22:11,  3.83s/it]
# Extracting paths from text with schema:  58%|█████▊    | 487/834 [18:31<17:34,  3.04s/it]
# Extracting paths from text with schema:  59%|█████▊    | 488/834 [18:32<13:46,  2.39s/it]
# Extracting paths from text with schema:  59%|█████▊    | 489/834 [18:34<13:38,  2.37s/it]
# Extracting paths from text with schema:  59%|█████▉    | 490/834 [18:42<22:12,  3.87s/it]
# Extracting paths from text with schema:  59%|█████▉    | 491/834 [18:45<20:29,  3.58s/it]
# Extracting paths from text with schema:  59%|█████▉    | 492/834 [18:48<20:17,  3.56s/it]
# Extracting paths from text with schema:  59%|█████▉    | 493/834 [18:49<15:29,  2.73s/it]
# Extracting paths from text with schema:  59%|█████▉    | 494/834 [18:53<17:17,  3.05s/it]
# Extracting paths from text with schema:  59%|█████▉    | 495/834 [18:55<16:32,  2.93s/it]
# Extracting paths from text with schema:  59%|█████▉    | 496/834 [18:56<12:46,  2.27s/it]
# Extracting paths from text with schema:  60%|█████▉    | 497/834 [18:59<13:45,  2.45s/it]
# Extracting paths from text with schema:  60%|█████▉    | 498/834 [18:59<10:32,  1.88s/it]
# Extracting paths from text with schema:  60%|█████▉    | 499/834 [19:03<13:35,  2.44s/it]
# Extracting paths from text with schema:  60%|█████▉    | 500/834 [19:06<14:19,  2.57s/it]
# Extracting paths from text with schema:  60%|██████    | 501/834 [19:06<10:40,  1.92s/it]
# Extracting paths from text with schema:  60%|██████    | 502/834 [19:09<11:25,  2.06s/it]
# Extracting paths from text with schema:  60%|██████    | 503/834 [19:10<10:10,  1.84s/it]
# Extracting paths from text with schema:  61%|██████    | 505/834 [19:14<10:23,  1.89s/it]
# Extracting paths from text with schema:  61%|██████    | 506/834 [19:15<08:33,  1.57s/it]
# Extracting paths from text with schema:  61%|██████    | 507/834 [19:18<10:44,  1.97s/it]
# Extracting paths from text with schema:  61%|██████    | 509/834 [19:18<06:41,  1.23s/it]
# Extracting paths from text with schema:  61%|██████    | 510/834 [19:20<07:05,  1.31s/it]
# Extracting paths from text with schema:  61%|██████▏   | 511/834 [19:21<07:01,  1.31s/it]
# Extracting paths from text with schema:  61%|██████▏   | 512/834 [19:22<06:00,  1.12s/it]
# Extracting paths from text with schema:  62%|██████▏   | 513/834 [19:24<07:32,  1.41s/it]
# Extracting paths from text with schema:  62%|██████▏   | 514/834 [19:26<08:03,  1.51s/it]
# Extracting paths from text with schema:  62%|██████▏   | 515/834 [19:27<07:50,  1.48s/it]
# Extracting paths from text with schema:  62%|██████▏   | 516/834 [19:28<06:26,  1.22s/it]
# Extracting paths from text with schema:  62%|██████▏   | 517/834 [19:29<06:01,  1.14s/it]
# Extracting paths from text with schema:  62%|██████▏   | 518/834 [19:29<05:36,  1.07s/it]
# Extracting paths from text with schema:  62%|██████▏   | 519/834 [19:31<06:35,  1.26s/it]
# Extracting paths from text with schema:  62%|██████▏   | 520/834 [19:32<06:29,  1.24s/it]
# Extracting paths from text with schema:  62%|██████▏   | 521/834 [19:35<08:34,  1.64s/it]
# Extracting paths from text with schema:  63%|██████▎   | 522/834 [19:41<15:38,  3.01s/it]
# Extracting paths from text with schema:  63%|██████▎   | 523/834 [19:44<14:56,  2.88s/it]
# Extracting paths from text with schema:  63%|██████▎   | 524/834 [19:45<11:44,  2.27s/it]
# Extracting paths from text with schema:  63%|██████▎   | 525/834 [19:48<13:24,  2.60s/it]
# Extracting paths from text with schema:  63%|██████▎   | 526/834 [19:52<14:49,  2.89s/it]
# Extracting paths from text with schema:  63%|██████▎   | 527/834 [19:52<10:49,  2.12s/it]
# Extracting paths from text with schema:  63%|██████▎   | 528/834 [19:54<11:24,  2.24s/it]
# Extracting paths from text with schema:  63%|██████▎   | 529/834 [19:55<09:39,  1.90s/it]
# Extracting paths from text with schema:  64%|██████▎   | 530/834 [19:56<07:29,  1.48s/it]
# Extracting paths from text with schema:  64%|██████▎   | 531/834 [19:58<08:32,  1.69s/it]
# Extracting paths from text with schema:  64%|██████▍   | 532/834 [19:59<06:50,  1.36s/it]
# Extracting paths from text with schema:  64%|██████▍   | 533/834 [20:01<08:00,  1.60s/it]
# Extracting paths from text with schema:  64%|██████▍   | 534/834 [20:02<07:23,  1.48s/it]
# Extracting paths from text with schema:  64%|██████▍   | 535/834 [20:05<09:36,  1.93s/it]
# Extracting paths from text with schema:  64%|██████▍   | 536/834 [20:06<07:40,  1.54s/it]
# Extracting paths from text with schema:  64%|██████▍   | 537/834 [20:08<08:54,  1.80s/it]
# Extracting paths from text with schema:  65%|██████▍   | 538/834 [20:14<14:44,  2.99s/it]
# Extracting paths from text with schema:  65%|██████▍   | 539/834 [20:16<13:57,  2.84s/it]
# Extracting paths from text with schema:  65%|██████▍   | 540/834 [20:18<12:13,  2.50s/it]
# Extracting paths from text with schema:  65%|██████▍   | 541/834 [20:19<09:33,  1.96s/it]
# Extracting paths from text with schema:  65%|██████▍   | 542/834 [20:36<31:55,  6.56s/it]
# Extracting paths from text with schema:  65%|██████▌   | 543/834 [20:39<26:15,  5.41s/it]
# Extracting paths from text with schema:  65%|██████▌   | 544/834 [20:46<29:24,  6.08s/it]
# Extracting paths from text with schema:  65%|██████▌   | 545/834 [20:47<21:09,  4.39s/it]
# Extracting paths from text with schema:  65%|██████▌   | 546/834 [20:51<20:08,  4.20s/it]
# Extracting paths from text with schema:  66%|██████▌   | 547/834 [20:53<17:49,  3.73s/it]
# Extracting paths from text with schema:  66%|██████▌   | 548/834 [20:54<13:26,  2.82s/it]
# Extracting paths from text with schema:  66%|██████▌   | 549/834 [20:58<15:11,  3.20s/it]
# Extracting paths from text with schema:  66%|██████▌   | 550/834 [21:00<13:06,  2.77s/it]
# Extracting paths from text with schema:  66%|██████▌   | 551/834 [21:02<12:45,  2.71s/it]
# Extracting paths from text with schema:  66%|██████▌   | 552/834 [21:06<13:23,  2.85s/it]
# ...
# Extracting paths from text with schema:  78%|███████▊  | 651/834 [26:00<06:54,  2.27s/it]
# Extracting paths from text with schema:  78%|███████▊  | 652/834 [26:03<07:34,  2.50s/it]
# Extracting paths from text with schema:  78%|███████▊  | 654/834 [26:04<04:23,  1.46s/it]
# Extracting paths from text with schema:  79%|███████▊  | 655/834 [26:07<05:32,  1.86s/it]
# Extracting paths from text with schema:  79%|███████▊  | 656/834 [26:11<07:30,  2.53s/it]
# Extracting paths from text with schema:  79%|███████▉  | 657/834 [26:15<08:27,  2.87s/it]
# Extracting paths from text with schema:  79%|███████▉  | 659/834 [26:25<10:54,  3.74s/it]
# Extracting paths from text with schema:  79%|███████▉  | 660/834 [26:29<11:06,  3.83s/it]
# Extracting paths from text with schema:  79%|███████▉  | 661/834 [26:32<10:24,  3.61s/it]
# Extracting paths from text with schema:  79%|███████▉  | 662/834 [26:36<11:01,  3.85s/it]
# Extracting paths from text with schema:  79%|███████▉  | 663/834 [26:39<10:19,  3.62s/it]
# Extracting paths from text with schema:  80%|███████▉  | 664/834 [26:43<10:07,  3.57s/it]
# Extracting paths from text with schema:  80%|███████▉  | 665/834 [26:45<08:41,  3.09s/it]
# Extracting paths from text with schema:  80%|███████▉  | 666/834 [26:47<07:52,  2.82s/it]
# Extracting paths from text with schema:  80%|███████▉  | 667/834 [26:49<07:38,  2.75s/it]
# Extracting paths from text with schema:  80%|████████  | 668/834 [26:52<07:18,  2.64s/it]
# Extracting paths from text with schema:  80%|████████  | 669/834 [26:56<08:28,  3.08s/it]
# Extracting paths from text with schema:  80%|████████  | 670/834 [26:57<07:08,  2.61s/it]
# Extracting paths from text with schema:  80%|████████  | 671/834 [27:02<09:00,  3.31s/it]
# Extracting paths from text with schema:  81%|████████  | 672/834 [27:06<09:20,  3.46s/it]
# Extracting paths from text with schema:  81%|████████  | 673/834 [27:07<06:52,  2.56s/it]
# Extracting paths from text with schema:  81%|████████  | 674/834 [27:08<05:42,  2.14s/it]
# Extracting paths from text with schema:  81%|████████  | 675/834 [27:09<05:03,  1.91s/it]
# Extracting paths from text with schema:  81%|████████  | 676/834 [27:10<03:56,  1.50s/it]
# Extracting paths from text with schema:  81%|████████  | 677/834 [27:12<04:15,  1.63s/it]
# Extracting paths from text with schema:  81%|████████▏ | 678/834 [27:13<03:38,  1.40s/it]
# Extracting paths from text with schema:  81%|████████▏ | 679/834 [27:13<03:13,  1.25s/it]
# Extracting paths from text with schema:  82%|████████▏ | 680/834 [27:17<05:05,  1.98s/it]
# Extracting paths from text with schema:  82%|████████▏ | 681/834 [27:17<03:43,  1.46s/it]
# Extracting paths from text with schema:  82%|████████▏ | 682/834 [27:20<04:57,  1.96s/it]
# Extracting paths from text with schema:  82%|████████▏ | 683/834 [27:22<04:46,  1.90s/it]
# Extracting paths from text with schema:  82%|████████▏ | 684/834 [27:25<05:09,  2.06s/it]
# Extracting paths from text with schema:  82%|████████▏ | 685/834 [27:26<04:35,  1.85s/it]
# Extracting paths from text with schema:  82%|████████▏ | 686/834 [27:31<06:53,  2.79s/it]
# Extracting paths from text with schema:  82%|████████▏ | 687/834 [27:34<06:59,  2.85s/it]
# Extracting paths from text with schema:  82%|████████▏ | 688/834 [27:35<05:46,  2.37s/it]
# Extracting paths from text with schema:  83%|████████▎ | 689/834 [27:38<05:49,  2.41s/it]
# Extracting paths from text with schema:  83%|████████▎ | 690/834 [27:39<05:13,  2.18s/it]
# Extracting paths from text with schema:  83%|████████▎ | 691/834 [27:42<05:41,  2.39s/it]
# Extracting paths from text with schema:  83%|████████▎ | 692/834 [27:45<05:49,  2.46s/it]
# Extracting paths from text with schema:  83%|████████▎ | 693/834 [27:45<04:11,  1.78s/it]
# Extracting paths from text with schema:  83%|████████▎ | 694/834 [27:46<03:24,  1.46s/it]
# Extracting paths from text with schema:  83%|████████▎ | 695/834 [27:50<05:00,  2.16s/it]
# Extracting paths from text with schema:  83%|████████▎ | 696/834 [27:50<03:36,  1.57s/it]
# Extracting paths from text with schema:  84%|████████▎ | 697/834 [27:50<02:38,  1.16s/it]
# Extracting paths from text with schema:  84%|████████▎ | 698/834 [27:50<01:57,  1.16it/s]
# Extracting paths from text with schema:  84%|████████▍ | 699/834 [27:53<03:34,  1.59s/it]
# Extracting paths from text with schema:  84%|████████▍ | 700/834 [27:57<04:50,  2.17s/it]
# Extracting paths from text with schema:  84%|████████▍ | 701/834 [27:58<03:56,  1.78s/it]
# Extracting paths from text with schema:  84%|████████▍ | 702/834 [28:01<04:55,  2.24s/it]
# Extracting paths from text with schema:  84%|████████▍ | 703/834 [28:02<04:16,  1.96s/it]
# Extracting paths from text with schema:  84%|████████▍ | 704/834 [28:04<04:03,  1.87s/it]
# Extracting paths from text with schema:  85%|████████▍ | 705/834 [28:06<03:54,  1.82s/it]
# Extracting paths from text with schema:  85%|████████▍ | 706/834 [28:08<04:07,  1.93s/it]
# Extracting paths from text with schema:  85%|████████▍ | 707/834 [28:09<03:39,  1.73s/it]
# Extracting paths from text with schema:  85%|████████▍ | 708/834 [28:12<04:03,  1.93s/it]
# Extracting paths from text with schema:  85%|████████▌ | 709/834 [28:12<02:59,  1.44s/it]
# Extracting paths from text with schema:  85%|████████▌ | 710/834 [28:18<06:05,  2.95s/it]
# Extracting paths from text with schema:  85%|████████▌ | 711/834 [28:22<06:27,  3.15s/it]
# Extracting paths from text with schema:  85%|████████▌ | 712/834 [28:26<07:01,  3.46s/it]
# Extracting paths from text with schema:  85%|████████▌ | 713/834 [28:30<06:58,  3.46s/it]
# Extracting paths from text with schema:  86%|████████▌ | 714/834 [28:34<07:17,  3.65s/it]
# Extracting paths from text with schema:  86%|████████▌ | 715/834 [28:37<07:13,  3.65s/it]
# Extracting paths from text with schema:  86%|████████▌ | 716/834 [28:38<05:22,  2.73s/it]
# Extracting paths from text with schema:  86%|████████▌ | 717/834 [28:42<06:02,  3.10s/it]
# Extracting paths from text with schema:  86%|████████▌ | 718/834 [28:43<04:54,  2.54s/it]
# Extracting paths from text with schema:  86%|████████▌ | 719/834 [28:46<05:12,  2.72s/it]
# Extracting paths from text with schema:  86%|████████▋ | 720/834 [28:47<04:07,  2.17s/it]
# Extracting paths from text with schema:  86%|████████▋ | 721/834 [28:48<03:21,  1.79s/it]
# Extracting paths from text with schema:  87%|████████▋ | 722/834 [29:01<09:18,  4.99s/it]
# Extracting paths from text with schema:  87%|████████▋ | 723/834 [29:01<06:53,  3.73s/it]
# Extracting paths from text with schema:  87%|████████▋ | 724/834 [29:05<06:34,  3.59s/it]
# Extracting paths from text with schema:  87%|████████▋ | 725/834 [29:06<05:07,  2.82s/it]
# Extracting paths from text with schema:  87%|████████▋ | 726/834 [29:08<05:01,  2.79s/it]
# Extracting paths from text with schema:  87%|████████▋ | 727/834 [29:11<04:46,  2.68s/it]
# Extracting paths from text with schema:  87%|████████▋ | 728/834 [29:12<04:07,  2.33s/it]
# Extracting paths from text with schema:  87%|████████▋ | 729/834 [29:14<03:54,  2.23s/it]
# Extracting paths from text with schema:  88%|████████▊ | 730/834 [29:17<03:52,  2.24s/it]
# Extracting paths from text with schema:  88%|████████▊ | 731/834 [29:21<04:52,  2.84s/it]
# Extracting paths from text with schema:  88%|████████▊ | 732/834 [29:21<03:34,  2.10s/it]
# Extracting paths from text with schema:  88%|████████▊ | 733/834 [29:22<03:06,  1.84s/it]
# Extracting paths from text with schema:  88%|████████▊ | 734/834 [29:24<02:48,  1.69s/it]
# Extracting paths from text with schema:  88%|████████▊ | 735/834 [29:25<02:22,  1.44s/it]
# Extracting paths from text with schema:  88%|████████▊ | 736/834 [29:27<02:51,  1.75s/it]
# Extracting paths from text with schema:  88%|████████▊ | 737/834 [29:29<02:46,  1.72s/it]
# Extracting paths from text with schema:  88%|████████▊ | 738/834 [29:32<03:24,  2.13s/it]
# Extracting paths from text with schema:  89%|████████▊ | 739/834 [29:36<04:28,  2.83s/it]
# Extracting paths from text with schema:  89%|████████▊ | 740/834 [29:37<03:21,  2.15s/it]
# Extracting paths from text with schema:  89%|████████▉ | 741/834 [29:38<02:51,  1.84s/it]
# Extracting paths from text with schema:  89%|████████▉ | 742/834 [29:40<03:06,  2.03s/it]
# Extracting paths from text with schema:  89%|████████▉ | 744/834 [29:42<02:00,  1.34s/it]
# Extracting paths from text with schema:  89%|████████▉ | 745/834 [29:44<02:34,  1.74s/it]
# Extracting paths from text with schema:  89%|████████▉ | 746/834 [29:45<02:11,  1.49s/it]
# Extracting paths from text with schema:  90%|████████▉ | 747/834 [29:49<03:07,  2.16s/it]
# Extracting paths from text with schema:  90%|████████▉ | 748/834 [29:52<03:23,  2.37s/it]
# Extracting paths from text with schema:  90%|████████▉ | 749/834 [29:57<04:19,  3.06s/it]
# Extracting paths from text with schema:  90%|█████████ | 751/834 [30:03<04:05,  2.96s/it]
# Extracting paths from text with schema:  90%|█████████ | 752/834 [30:04<03:41,  2.70s/it]
# Extracting paths from text with schema:  90%|█████████ | 753/834 [30:05<02:47,  2.06s/it]
# Extracting paths from text with schema:  90%|█████████ | 754/834 [30:07<02:59,  2.24s/it]
# Extracting paths from text with schema:  91%|█████████ | 755/834 [30:08<02:28,  1.89s/it]
# Extracting paths from text with schema:  91%|█████████ | 756/834 [30:11<02:50,  2.18s/it]
# Extracting paths from text with schema:  91%|█████████ | 757/834 [30:13<02:27,  1.91s/it]
# Extracting paths from text with schema:  91%|█████████ | 758/834 [30:18<03:39,  2.88s/it]
# Extracting paths from text with schema:  91%|█████████ | 759/834 [30:20<03:24,  2.72s/it]
# Extracting paths from text with schema:  91%|█████████ | 760/834 [30:24<03:46,  3.07s/it]
# Extracting paths from text with schema:  91%|█████████ | 761/834 [30:32<05:20,  4.39s/it]
# Extracting paths from text with schema:  91%|█████████▏| 762/834 [30:33<04:09,  3.46s/it]
# Extracting paths from text with schema:  91%|█████████▏| 763/834 [30:38<04:35,  3.88s/it]
# Extracting paths from text with schema:  92%|█████████▏| 764/834 [30:38<03:14,  2.78s/it]
# Extracting paths from text with schema:  92%|█████████▏| 765/834 [30:39<02:40,  2.32s/it]
# Extracting paths from text with schema:  92%|█████████▏| 766/834 [30:44<03:19,  2.93s/it]
# Extracting paths from text with schema:  92%|█████████▏| 767/834 [30:45<02:47,  2.50s/it]
# Extracting paths from text with schema:  92%|█████████▏| 768/834 [30:47<02:40,  2.43s/it]
# Extracting paths from text with schema:  92%|█████████▏| 769/834 [30:48<02:09,  1.99s/it]
# Extracting paths from text with schema:  92%|█████████▏| 770/834 [30:49<01:38,  1.54s/it]
# Extracting paths from text with schema:  93%|█████████▎| 772/834 [30:51<01:27,  1.41s/it]
# Extracting paths from text with schema:  93%|█████████▎| 773/834 [30:52<01:10,  1.15s/it]
# Extracting paths from text with schema:  93%|█████████▎| 774/834 [30:53<01:06,  1.11s/it]
# Extracting paths from text with schema:  93%|█████████▎| 775/834 [30:56<01:37,  1.65s/it]
# Extracting paths from text with schema:  93%|█████████▎| 776/834 [30:57<01:24,  1.45s/it]
# Extracting paths from text with schema:  93%|█████████▎| 777/834 [30:57<01:02,  1.10s/it]
# Extracting paths from text with schema:  93%|█████████▎| 778/834 [31:00<01:30,  1.62s/it]
# Extracting paths from text with schema:  94%|█████████▎| 780/834 [31:01<01:04,  1.20s/it]
# Extracting paths from text with schema:  94%|█████████▎| 781/834 [31:03<01:18,  1.48s/it]
# Extracting paths from text with schema:  94%|█████████▍| 782/834 [31:04<01:00,  1.16s/it]
# Extracting paths from text with schema:  94%|█████████▍| 783/834 [31:05<00:59,  1.16s/it]
# Extracting paths from text with schema:  94%|█████████▍| 784/834 [31:08<01:27,  1.75s/it]
# Extracting paths from text with schema:  94%|█████████▍| 785/834 [31:12<01:55,  2.35s/it]
# Extracting paths from text with schema:  94%|█████████▍| 786/834 [31:14<01:51,  2.32s/it]
# Extracting paths from text with schema:  94%|█████████▍| 787/834 [31:16<01:39,  2.11s/it]
# Extracting paths from text with schema:  94%|█████████▍| 788/834 [31:17<01:19,  1.73s/it]
# Extracting paths from text with schema:  95%|█████████▍| 789/834 [31:25<02:46,  3.70s/it]
# Extracting paths from text with schema:  95%|█████████▍| 791/834 [31:29<02:06,  2.93s/it]
# Extracting paths from text with schema:  95%|█████████▍| 792/834 [31:32<01:59,  2.84s/it]
# Extracting paths from text with schema:  95%|█████████▌| 793/834 [31:37<02:25,  3.55s/it]
# Extracting paths from text with schema:  95%|█████████▌| 794/834 [31:39<02:02,  3.05s/it]
# Extracting paths from text with schema:  95%|█████████▌| 795/834 [31:41<01:48,  2.79s/it]
# Extracting paths from text with schema:  95%|█████████▌| 796/834 [31:46<02:09,  3.41s/it]
# Extracting paths from text with schema:  96%|█████████▌| 797/834 [31:47<01:36,  2.60s/it]
# Extracting paths from text with schema:  96%|█████████▌| 798/834 [31:50<01:41,  2.83s/it]
# Extracting paths from text with schema:  96%|█████████▌| 799/834 [31:51<01:19,  2.26s/it]
# Extracting paths from text with schema:  96%|█████████▌| 800/834 [31:51<00:56,  1.67s/it]
# Extracting paths from text with schema:  96%|█████████▌| 801/834 [31:56<01:23,  2.54s/it]
# Extracting paths from text with schema:  96%|█████████▌| 802/834 [31:56<01:00,  1.89s/it]
# Extracting paths from text with schema:  96%|█████████▋| 803/834 [31:59<01:05,  2.10s/it]
# Extracting paths from text with schema:  96%|█████████▋| 804/834 [32:00<00:57,  1.90s/it]
# Extracting paths from text with schema:  97%|█████████▋| 805/834 [32:03<01:02,  2.17s/it]
# Extracting paths from text with schema:  97%|█████████▋| 806/834 [32:04<00:49,  1.78s/it]
# Extracting paths from text with schema:  97%|█████████▋| 807/834 [32:08<01:10,  2.62s/it]
# Extracting paths from text with schema:  97%|█████████▋| 808/834 [32:13<01:20,  3.10s/it]
# Extracting paths from text with schema:  97%|█████████▋| 809/834 [32:14<01:04,  2.56s/it]
# Extracting paths from text with schema:  97%|█████████▋| 810/834 [32:19<01:20,  3.37s/it]
# Extracting paths from text with schema:  97%|█████████▋| 811/834 [32:24<01:29,  3.89s/it]
# Extracting paths from text with schema:  97%|█████████▋| 813/834 [32:25<00:44,  2.14s/it]
# Extracting paths from text with schema:  98%|█████████▊| 814/834 [32:25<00:33,  1.69s/it]
# Extracting paths from text with schema:  98%|█████████▊| 815/834 [32:28<00:40,  2.14s/it]
# Extracting paths from text with schema:  98%|█████████▊| 816/834 [32:29<00:30,  1.72s/it]
# Extracting paths from text with schema:  98%|█████████▊| 817/834 [32:35<00:50,  2.98s/it]
# Extracting paths from text with schema:  98%|█████████▊| 818/834 [32:39<00:52,  3.27s/it]
# Extracting paths from text with schema:  98%|█████████▊| 819/834 [32:42<00:48,  3.20s/it]
# Extracting paths from text with schema:  98%|█████████▊| 820/834 [32:44<00:38,  2.73s/it]
# Extracting paths from text with schema:  98%|█████████▊| 821/834 [32:46<00:32,  2.52s/it]
# Extracting paths from text with schema:  99%|█████████▊| 822/834 [32:48<00:28,  2.34s/it]
# Extracting paths from text with schema:  99%|█████████▊| 823/834 [32:49<00:23,  2.11s/it]
# Extracting paths from text with schema:  99%|█████████▉| 824/834 [32:51<00:19,  1.96s/it]
# Extracting paths from text with schema:  99%|█████████▉| 825/834 [32:55<00:22,  2.51s/it]
# Extracting paths from text with schema:  99%|█████████▉| 826/834 [32:55<00:15,  1.92s/it]
# Extracting paths from text with schema:  99%|█████████▉| 827/834 [32:57<00:13,  1.89s/it]
# Extracting paths from text with schema:  99%|█████████▉| 828/834 [33:00<00:13,  2.32s/it]
# Extracting paths from text with schema:  99%|█████████▉| 829/834 [33:04<00:13,  2.76s/it]
# Extracting paths from text with schema: 100%|█████████▉| 830/834 [33:11<00:16,  4.06s/it]
# Extracting paths from text with schema: 100%|█████████▉| 831/834 [33:12<00:09,  3.04s/it]
# Extracting paths from text with schema: 100%|█████████▉| 832/834 [33:15<00:06,  3.04s/it]
# Extracting paths from text with schema: 100%|█████████▉| 833/834 [33:31<00:07,  7.05s/it]
# Extracting paths from text with schema: 100%|██████████| 834/834 [33:38<00:00,  2.42s/it]
# Generating embeddings:   0%|          | 0/834 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/6350 [00:00<?, ?it/s]

# %%
# save and load using locally stored graphs if you dont want to implement neo4j, you can directly use locally stored index in storage folder
index.storage_context.persist(persist_dir="./storage")

index = load_index_from_storage(
    StorageContext.from_defaults(persist_dir="./storage")
)

# %%
# load from existing graph/vector store
index = PropertyGraphIndex.from_existing(
    property_graph_store=graph_store
)

# %% [markdown]
# # Querying GraphRAG

# %%
# Define retriever
retriever = index.as_retriever(
    include_text=False,  # Default is true
)
results = retriever.retrieve("What is the summary of the texts?")
for record in results:
    print(record.text)
# Out:
# Senescau A -> WORKED_ON -> Innovative DendrisChipsÂ® Technology for a Syndromic Approach of In Vitro Diagnosis: Application to the Respiratory Infectious Diseases
# Hsueh, P.R. -> WORKED_ON -> Decreasing rates of resistance to pencillin, but not erythromycin, in Streptococcus pneumoniae after introduction of a policy to restrict antibiotic use in Taiwan
# Hsueh, P. -> WORKED_ON -> Decreased erythromycin use after antimicrobial reimbursement restriction for undocumented bacterial upper respiratory tract infections significantly reduced erythromycin resistance in Streptococcus pyogenes in Taiwan
# Hsueh, P.R. -> WORKED_ON -> Changes in macrolide resistance among respiratory pathogens after decreased erythromycin consumption in Taiwan

# %%
query_engine = index.as_query_engine(include_text=True)
response = query_engine.query("Create a summary of 5 notable AI-driven drugs discovered for antibiotic resistance")
print(response)
# Out:
# 1. Cesar de la Fuente and team have utilized AI and machine learning to accelerate the discovery and development of antimicrobial peptides, reducing the timeline significantly.
# 2. Berman and Krysan have worked on drug resistance and tolerance in fungi, showcasing the potential of AI in addressing antifungal resistance.
# 3. L. Zurek and A. Ghosh have collaborated on research linking insects to the spread of antibiotic resistance traits, highlighting the importance of understanding diverse pathways of resistance.
# 4. R. Laxminarayan has contributed to the global need for solutions in antibiotic resistance, emphasizing the urgency for innovative approaches in combating resistance.
# 5. Cuomo and Rogers have delved into the molecular and genetic basis of antifungal resistance in emerging pathogens like Candida auris, demonstrating the application of AI in understanding resistance mechanisms.

# %%
query_engine = index.as_query_engine(include_text=True)
response = query_engine.query("Give an example of AI being used to discover drugs for antibiotic resistance")
print(response)
# Out:
# de Heer K worked on the detection of invasive pulmonary aspergillosis using electronic nose technology, which is an example of AI being used to discover drugs for antibiotic resistance.

# %%
query_engine = index.as_query_engine(include_text=True)
response = query_engine.query("What is invasive pulmonary aspergillosis?")
print(response)
# Out:
# Invasive pulmonary aspergillosis is a severe fungal infection caused by the Aspergillus species that primarily affects the lungs.

# %%
query_engine = index.as_query_engine(include_text=True)
response = query_engine.query("What contribution has Regina Barzilay made to AI-driven drugs discovery?")
print(response)
# Out:
# Regina Barzilay has not been mentioned in the provided context information.

# %%
query_engine = index.as_query_engine(include_text=True)
response = query_engine.query("What contribution has Alexander Fleming made to AI-driven drugs discovery?")
print(response)
# Out:
# Alexander Fleming's contribution to AI-driven drug discovery is not mentioned in the provided context information.
